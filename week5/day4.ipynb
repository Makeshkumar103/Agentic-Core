# %% [markdown]
# # RAG Day 4
#
# ## Evaluation!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Keep in mind how you would evaluate RAG for your business</h2>
#             <span style="color:#181;">This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!</span>
#         </td>
#     </tr>
# </table>

# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.16666666666666666, ndcg=0.29420493957109245, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 eval, answer, chunks = evaluate_answer(example)
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\week5\evaluation\eval.py:129, in evaluate_answer(test)
#     119 """
#     120 Evaluate answer quality using LLM-as-a-judge (async).
#     121
#    (...)    126     Tuple of (AnswerEval object, generated_answer string, retrieved_docs list)
#     127 """
#     128 # Get RAG response using shared answer module
# --> 129 generated_answer, retrieved_docs = answer_question(test.question)
#     131 # LLM judge prompt
#     132 judge_messages = [
#     133     {
#     134         "role": "system",
#    (...)    154     },
#     155 ]
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\week5\implementation\answer.py:68, in answer_question(question, history)
#      66 messages.extend(convert_to_messages(history))
#      67 messages.append(HumanMessage(content=question))
# ---> 68 response = llm.invoke(messages)
#      69 return response.content, docs
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:382, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     368 @override
#     369 def invoke(
#     370     self,
#    (...)    375     **kwargs: Any,
#     376 ) -> AIMessage:
#     377     config = ensure_config(config)
#     378     return cast(
#     379         "AIMessage",
#     380         cast(
#     381             "ChatGeneration",
# --> 382             self.generate_prompt(
#     383                 [self._convert_input(input)],
#     384                 stop=stop,
#     385                 callbacks=config.get("callbacks"),
#     386                 tags=config.get("tags"),
#     387                 metadata=config.get("metadata"),
#     388                 run_name=config.get("run_name"),
#     389                 run_id=config.pop("run_id", None),
#     390                 **kwargs,
#     391             ).generations[0][0],
#     392         ).message,
#     393     )
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1101, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1092 @override
#    1093 def generate_prompt(
#    1094     self,
#    (...)   1098     **kwargs: Any,
#    1099 ) -> LLMResult:
#    1100     prompt_messages = [p.to_messages() for p in prompts]
# -> 1101     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:911, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     908 for i, m in enumerate(input_messages):
#     909     try:
#     910         results.append(
# --> 911             self._generate_with_cache(
#     912                 m,
#     913                 stop=stop,
#     914                 run_manager=run_managers[i] if run_managers else None,
#     915                 **kwargs,
#     916             )
#     917         )
#     918     except BaseException as e:
#     919         if run_managers:
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1205, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1203     result = generate_from_stream(iter(chunks))
#    1204 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1205     result = self._generate(
#    1206         messages, stop=stop, run_manager=run_manager, **kwargs
#    1207     )
#    1208 else:
#    1209     result = self._generate(messages, stop=stop, **kwargs)
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1299, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1297     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1298         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1299     raise e
#    1300 if (
#    1301     self.include_response_headers
#    1302     and raw_response is not None
#    1303     and hasattr(raw_response, "headers")
#    1304 ):
#    1305     generation_info = {"headers": dict(raw_response.headers)}
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1294, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1287         return _construct_lc_result_from_responses_api(
#    1288             response,
#    1289             schema=original_schema_obj,
#    1290             metadata=generation_info,
#    1291             output_version=self.output_version,
#    1292         )
#    1293     else:
# -> 1294         raw_response = self.client.with_raw_response.create(**payload)
#    1295         response = raw_response.parse()
#    1296 except Exception as e:
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Lib\site-packages\openai\_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     360 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File e:\MK\AI projects\Agentic-core\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': "model 'gemma3.2:1b' not found", 'type': 'not_found_error', 'param': None, 'code': None}}

# %%
eval
# Out:
# <function eval(source, globals=None, locals=None, /)>

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(eval.feedback)
#       2 print(eval.accuracy)
#       3 print(eval.completeness)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'feedback'
